# %%
from pathlib import Path
val = '/images'
# val = [Path(x).resolve() for x in (val if isinstance(val, list) else [val])]

val = [Path(x).resolve() for x in val]

# %%
import matplotlib.pyplot as plt
import cv2

img_path = '/data.local/hangd/data_vtx/frames_data/train/NVR-CH01_S20210607-095007_E20210607-095126/frame_000343.jpg'
img = cv2.imread(img_path)

plt.imshow(img)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
# from PIL import Image

# with Image.open("/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/dataset/frame_000000.jpg") as im:

#     # Provide the target width and height of the image
#     (width, height) = (640, 640)
#     im_resized = im.resize((width, height))
#     im_resized.save('/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/dataset/frame_000000.jpg')

# %%
import torch

path = '/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/pretrained/crowdhuman_yolov5m.pt'
ckpt_5m = torch.load(path)

# %%
for key in ckpt_5m:
    print(key)
# Out:
# epoch
# best_fitness
# training_results
# model
# optimizer
# wandb_id

# %%
yolov5s = '/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/pretrained/yolov5s.pt'
ckpt_5s = torch.load(yolov5s)

for key in ckpt_5s:
    print(key)
# Out:
# epoch
# best_fitness
# training_results
# model
# optimizer
# wandb_id

# %%
ckpt_5m['model']
# Out:
# Model(
#   (model): Sequential(
#     (0): Focus(
#       (conv): Conv(
#         (conv): Conv2d(12, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#     )
#     (1): Conv(
#       (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
# ckpt_5s['model']

# %%
# (1): Conv2d(384, 21, kernel_size=(1, 1), stride=(1, 1))
# (2): Conv2d(768, 21, kernel_size=(1, 1), stride=(1, 1))

# %%
# yolo5m_coco = '/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/checkpoints/yolov5m.pt'
# ckpt_5m_coco = torch.load(yolo5m_coco)
# ckpt_5m_coco['model']

# (1): Conv2d(384, 255, kernel_size=(1, 1), stride=(1, 1))
# (2): Conv2d(768, 255, kernel_size=(1, 1), stride=(1, 1))
# Out:
# Model(
#   (model): Sequential(
#     (0): Focus(
#       (conv): Conv(
#         (conv): Conv2d(12, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#     )
#     (1): Conv(
#       (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
new_path = '/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/runs/train/exp32/weights/best.pt'
new = torch.load(new_path)

for key in new:
    print(key)
new['model']
# Out:
# epoch
# best_fitness
# training_results
# model
# ema
# updates
# optimizer
# wandb_id
# Model(
#   (model): Sequential(
#     (0): Focus(
#       (conv): Conv(
#         (conv): Conv2d(12, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#     )
#     (1): Conv(
#       (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !python detect.py --source /data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/dataset/frame_009381.jpg --weights /data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/runs/train/exp32/weights/best.pt
# Out:
# Namespace(weights=['/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/yolov5/runs/train/exp32/weights/best.pt'], source='/data.local/all/hainp/yolov5_deep_sort/YoloV5_Deepsort_pytorch_clone/dataset/frame_009381.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# YOLOv5 🚀 fb4e293 torch 1.9.0+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.0625MB)
#                                    CUDA:1 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# ...

# %%
new['training_results']

# %%
# !python detect.py --weights runs/train/exp33/weights/last.pt \
  --img 640 --conf 0.4 --source ../dataset/frame_009381.jpg
# Out:
# Namespace(weights=['runs/train/exp33/weights/last.pt'], source='../dataset/frame_009381.jpg', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# YOLOv5 🚀 fb4e293 torch 1.9.0+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.0625MB)
#                                    CUDA:1 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# /home/hangd/.conda/envs/deep-sort/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# ...
